# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# %%
PATH_DATA = '../mydata/'

# %%
df = pd.read_csv("indonesian_movies.csv")

# %%
df
# Out:
#                          title  year  \
# 0          #FriendButMarried 2  2020
# 1                     4 Mantan  2020
# 2     Aku Tahu Kapan Kamu Mati  2020
# 3                  Anak Garuda  2020
# 4                    Dignitate  2020
# ...                        ...   ...
# 1267     The Tiger from Tjampa  1953
# 1268       Enam Djam di Djogja  1951
# 1269             Darah dan Doa  1950
# 1270         Resia Boroboedoer  1928
# 1271        Loetoeng Kasaroeng  1926
#
#                                             description      genre rating  \
# 0     Ayudia (Mawar De Jongh) is not satisfied enoug...  Biography    13+
# 1     Sara, Airin, Rachel, and Amara were accidental...   Thriller    17+
# 2     After apparent death, Siena is able to see sig...     Horror    13+
# 3     Good Morning Indonesia, a school for poor orph...  Adventure    13+
# 4     Alfi (Al Ghazali) meets Alana (Caitlin Halderm...      Drama    17+
# ...

# %%
group_status = df.groupby('users_rating')
group_status['users_rating'].size()
# Out:
# users_rating
# 1.2    1
# 1.4    2
# 1.5    1
# 1.6    1
# 1.7    2
#       ..
# 8.8    4
# 8.9    1
# 9.1    2
# 9.2    1
# 9.4    1
# Name: users_rating, Length: 79, dtype: int64

# %%
df_rating_lebihdari7 = df[df["users_rating"] > 7.0]
df_rating_lebihdari7.head()
# Out:
#                                  title  year  \
# 3                          Anak Garuda  2020
# 4                            Dignitate  2020
# 9                             Mariposa  2020
# 12  Nanti Kita Cerita Tentang Hari Ini  2020
# 15                 Si Doel the Movie 3  2020
#
#                                           description      genre rating  \
# 3   Good Morning Indonesia, a school for poor orph...  Adventure    13+
# 4   Alfi (Al Ghazali) meets Alana (Caitlin Halderm...      Drama    17+
# 9   Iqbal (Angga Yunanda) is like a Mariposa butte...      Drama    13+
# 12  Three siblings live in happy-looking families,...      Drama    13+
# 15  The return of Sarah with his son, Dul, to Jaka...      Drama    13+
#
#     users_rating votes   languages              directors  \
# 3            9.1    27  Indonesian           Faozan Rizal
# 4            7.6    33  Indonesian           Fajar Nugros
# 9            8.5    54  Indonesian          Fajar Bustomi
# ...

# %%
df_rating_lebihdari8 = df[df["users_rating"] > 8.0]
df_rating_lebihdari8.head()
# Out:
#                                       title  year  \
# 3                               Anak Garuda  2020
# 9                                  Mariposa  2020
# 22                          27 Steps of May  2019
# 29                          Anak Muda Palsu  2019
# 52  Horas Amang: Tiga Bulan Untuk Selamanya  2019
#
#                                           description      genre rating  \
# 3   Good Morning Indonesia, a school for poor orph...  Adventure    13+
# 9   Iqbal (Angga Yunanda) is like a Mariposa butte...      Drama    13+
# 22  Following a horrible experience, May has isola...      Drama    17+
# 29  Tumming, Abu, Illank, and Darwis, the final se...     Comedy    13+
# 52  The story of a family that is not harmonious: ...     Comedy    13+
#
#     users_rating votes   languages           directors  \
# 3            9.1    27  Indonesian        Faozan Rizal
# 9            8.5    54  Indonesian       Fajar Bustomi
# 22           8.2   280  Indonesian    Ravi L. Bharwani
# ...

# %%
df_rating_lebihdari9 = df[df["users_rating"] > 9.0]
df_rating_lebihdari9.head()
# Out:
#                                         title  year  \
# 3                                 Anak Garuda  2020
# 52    Horas Amang: Tiga Bulan Untuk Selamanya  2019
# 172  Jelita Sejuba: Mencintai Kesatria Negara  2018
# 496                            Salisiah Adaik  2013
#
#                                            description      genre rating  \
# 3    Good Morning Indonesia, a school for poor orph...  Adventure    13+
# 52   The story of a family that is not harmonious: ...     Comedy    13+
# 172  Without dating, Jaka immediately proposes for ...      Drama    13+
# 496                                                NaN      Drama     SU
#
#      users_rating votes   languages           directors  \
# 3             9.1    27  Indonesian        Faozan Rizal
# 52            9.4    16  Indonesian  Irham Acho Bahtiar
# 172           9.1   240  Indonesian          Ray Nayoan
# 496           9.2    19  Indonesian      Ferdinand Almi
#
# ...
